# %%
import os
import pandas as pd
import json
import numpy as np

# File directories 
input_directory = r'C:\Users\James\Desktop\Raw\logRaws'
output_directory = r'C:\Users\James\Desktop\Raw\userInfo'


# Preprocess data for a single file
def preprocess_single_file(input_file_path, output_file_path):

    # Load CSV data and filter rows where Swing Stage is not 0 (swing stage != 0, 3 fltrd_accel, 3 fltrd_gyro)
    input_data = pd.read_csv(input_file_path)
    # input_data = input_data[input_data.iloc[:, 3] != 0]
    input_data = input_data.iloc[:, [3, 19, 20, 21, 25, 26, 27]]

    X = np.array(input_data.values)

    if X.shape[0] != 999:
        print("not right format")    
        
    # Load JSON data -> If output is not available, skip
    with open(output_file_path, 'r') as json_file:
        try:
            output_data = json.load(json_file)
            Y = np.array(output_data['ShotResult'])
        except KeyError as e:
            return None, None

    
    return X, Y


def preprocess_all_files():
    
    # Consolidated Data from All Files
    all_data = []
    # Iterate through all files
    for input_file in os.listdir(input_directory):

        # Construct the output file path based on the common prefix
        common_prefix = '_'.join(input_file.split('_')[:-1]) + '_'
        output_file = common_prefix + 'userinfo.json'
        output_file_path = os.path.join(output_directory, output_file)

        # Construct the input file path
        input_file_path = os.path.join(input_directory, input_file)

        # Preprocess the data for the current file
        X, Y = preprocess_single_file(input_file_path, output_file_path)
    
        # Append the preprocessed data to the list if both values exist
        if X is not None and Y is not None:
            all_data.append((X, Y))


    return all_data

# preprocess_single_file(r"C:\Users\James\Desktop\Raw\logRaws\20230916_01_16_54_377_1018_logRaws.csv",r"C:\Users\James\Desktop\Raw\userInfo\20230916_01_16_54_377_1018_userinfo.json")
data = preprocess_all_files()
# Out:
#      0.1  -0.5965634  0.763303936  0.313128  0.00106422522.1  -0.00134013547  \
# 0      0   -0.597617     0.763061  0.310919         0.001064       -0.001866
# 1      0   -0.591784     0.764445  0.308718         0.001064       -0.001686
# 2      0   -0.592281     0.761976  0.305054         0.001064       -0.001981
# 3      0   -0.593423     0.758061  0.304973         0.001064       -0.002079
# 4      0   -0.593316     0.760337  0.310967         0.001064       -0.002128
# ..   ...         ...          ...       ...              ...             ...
# 994    4    0.795719    -0.133411 -0.088403        -0.709796       -0.800181
# 995    4    0.875266    -0.128617 -0.130379        -0.339829       -0.017343
# 996    4    0.922289    -0.140203 -0.142255        -0.208702        0.346477
# 997    4    0.925106    -0.161155 -0.149144        -0.236296        0.207371
# 998    4    0.908141    -0.181648 -0.165437        -0.324247       -0.358340
#
#      1.45984257E-06
# 0          0.000393
# 1          0.001064
# 2          0.000355
# 3          0.000118
# 4          0.000466
# ..              ...
# 994       -0.252976
# 995       -0.283690
# 996       -0.308827
# 997       -0.294148
# 998       -0.230723
#
# [999 rows x 7 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\James\Documents\GitHub\IMU_Golf_ML\5. swingmapping\data_preprocessing.ipynb Cell 1 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a>     return all_data
#      <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=57'>58</a> # preprocess_single_file(r"C:\Users\James\Desktop\Raw\logRaws\20230916_01_16_54_377_1018_logRaws.csv",r"C:\Users\James\Desktop\Raw\userInfo\20230916_01_16_54_377_1018_userinfo.json")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=58'>59</a> data = preprocess_all_files()
#
# c:\Users\James\Documents\GitHub\IMU_Golf_ML\5. swingmapping\data_preprocessing.ipynb Cell 1 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=50'>51</a>     # Append the preprocessed data to the list if both values exist
#      <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=51'>52</a>     if X is not None and Y is not None:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=52'>53</a>         all_data.append(X, Y)
#      <a href='vscode-notebook-cell:/c%3A/Users/James/Documents/GitHub/IMU_Golf_ML/5.%20swingmapping/data_preprocessing.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a> return all_data
#
# TypeError: list.append() takes exactly one argument (2 given)
