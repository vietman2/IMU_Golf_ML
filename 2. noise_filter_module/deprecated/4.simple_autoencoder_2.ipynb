# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Flatten, Dense, Reshape, Input
from tensorflow.keras.models import Model
from tensorflow.keras import Sequential

def simple_autoencoder():
    autoencoder = Sequential([
        # Encoder
        Input(shape=(1000, 1)),
        Flatten(),
        Dense(500, activation='relu'),
        Dense(250, activation='relu'),
        Dense(125, activation='relu'),

        # Decoder
        Dense(250, activation='relu'),
        Dense(500, activation='relu'),
        Dense(1000, activation='tanh'),
        Reshape((1000, 1))
    ])

    return autoencoder

# %%
DIR = "../data/Raw/logRaws/"

NUM_SAMPLES = 2662
NUM_FEATURES = 1
NUM_FRAMES = 1000

file_names = os.listdir(DIR)
input_array = np.empty((NUM_SAMPLES, NUM_FRAMES, NUM_FEATURES))

# prepare data
def read_files(DIR):
    all_files = os.listdir(DIR)

    input_data = np.empty((0, 1), float)

    for file in all_files:
        file_path = os.path.join(DIR, file)
        df = pd.read_csv(file_path, usecols=[1, 16], header=None)
        if df.shape[0] < 999:
            continue

        df.columns = ['frame', 'accel_x']
        df_input = df[['accel_x']]
        df_input = df_input.astype('float32')

        input_data = np.append(input_data, df_input, axis=0)
    input_data = input_data.reshape(NUM_SAMPLES, NUM_FRAMES, NUM_FEATURES)

    # divide by 16 to normalize
    input_data = input_data / 16

    return input_data

input_data = read_files(DIR)

input_data.shape
# Out:
# (2662, 1000, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(input_data, test_size=0.2, random_state=42)

# compile autoencoder
autoencoder = simple_autoencoder()
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()

# train autoencoder
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=32,
                validation_data=(X_test, X_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 1000)              0
#
#  dense_6 (Dense)             (None, 500)               500500
#
#  dense_7 (Dense)             (None, 250)               125250
#
#  dense_8 (Dense)             (None, 125)               31375
#
#  dense_9 (Dense)             (None, 250)               31500
#
#  dense_10 (Dense)            (None, 500)               125500
#
#  dense_11 (Dense)            (None, 1000)              501000
#
#  reshape_1 (Reshape)         (None, 1000, 1)           0
#
# =================================================================
# Total params: 1315125 (5.02 MB)
# Trainable params: 1315125 (5.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 67/67 [==============================] - 2s 18ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 2/50
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 3/50
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 4/50
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 5/50
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 6/50
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 7/50
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 8/50
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 9/50
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 10/50
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 11/50
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 12/50
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 13/50
# 67/67 [==============================] - 1s 18ms/step - loss: 9.7474e-04 - val_loss: 0.0011
# Epoch 14/50
# 67/67 [==============================] - 1s 17ms/step - loss: 9.7049e-04 - val_loss: 0.0011
# Epoch 15/50
# 67/67 [==============================] - 1s 16ms/step - loss: 9.3779e-04 - val_loss: 0.0011
# Epoch 16/50
# 67/67 [==============================] - 1s 17ms/step - loss: 9.0630e-04 - val_loss: 0.0011
# Epoch 17/50
# 67/67 [==============================] - 1s 16ms/step - loss: 8.7505e-04 - val_loss: 0.0011
# Epoch 18/50
# 67/67 [==============================] - 1s 16ms/step - loss: 8.6749e-04 - val_loss: 0.0010
# Epoch 19/50
# 67/67 [==============================] - 1s 17ms/step - loss: 8.1919e-04 - val_loss: 0.0010
# Epoch 20/50
# 67/67 [==============================] - 1s 18ms/step - loss: 7.9937e-04 - val_loss: 0.0010
# Epoch 21/50
# 67/67 [==============================] - 1s 18ms/step - loss: 7.9729e-04 - val_loss: 0.0010
# Epoch 22/50
# 67/67 [==============================] - 1s 17ms/step - loss: 7.8876e-04 - val_loss: 0.0010
# Epoch 23/50
# 67/67 [==============================] - 1s 17ms/step - loss: 7.8815e-04 - val_loss: 0.0010
# Epoch 24/50
# 67/67 [==============================] - 1s 16ms/step - loss: 7.6088e-04 - val_loss: 0.0010
# Epoch 25/50
# 67/67 [==============================] - 1s 16ms/step - loss: 7.3414e-04 - val_loss: 9.9945e-04
# Epoch 26/50
# 67/67 [==============================] - 1s 17ms/step - loss: 6.9590e-04 - val_loss: 9.9653e-04
# Epoch 27/50
# 67/67 [==============================] - 1s 16ms/step - loss: 6.7614e-04 - val_loss: 9.6733e-04
# Epoch 28/50
# 67/67 [==============================] - 1s 16ms/step - loss: 6.6577e-04 - val_loss: 9.7180e-04
# Epoch 29/50
# 67/67 [==============================] - 1s 16ms/step - loss: 6.4725e-04 - val_loss: 9.6045e-04
# Epoch 30/50
# 67/67 [==============================] - 1s 17ms/step - loss: 6.3581e-04 - val_loss: 9.6162e-04
# Epoch 31/50
# 67/67 [==============================] - 1s 16ms/step - loss: 6.2620e-04 - val_loss: 9.4156e-04
# Epoch 32/50
# 67/67 [==============================] - 1s 17ms/step - loss: 6.1186e-04 - val_loss: 9.5122e-04
# Epoch 33/50
# 67/67 [==============================] - 1s 16ms/step - loss: 6.0301e-04 - val_loss: 9.4692e-04
# Epoch 34/50
# 67/67 [==============================] - 1s 17ms/step - loss: 5.9194e-04 - val_loss: 9.2760e-04
# Epoch 35/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.7432e-04 - val_loss: 9.2529e-04
# Epoch 36/50
# 67/67 [==============================] - 1s 17ms/step - loss: 5.7312e-04 - val_loss: 9.3844e-04
# Epoch 37/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.6107e-04 - val_loss: 9.4172e-04
# Epoch 38/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.5301e-04 - val_loss: 9.2138e-04
# Epoch 39/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.5334e-04 - val_loss: 9.4197e-04
# Epoch 40/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.5305e-04 - val_loss: 9.2132e-04
# Epoch 41/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.4011e-04 - val_loss: 9.2592e-04
# Epoch 42/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.2731e-04 - val_loss: 9.0965e-04
# Epoch 43/50
# 67/67 [==============================] - 1s 17ms/step - loss: 5.1678e-04 - val_loss: 9.1978e-04
# Epoch 44/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.0412e-04 - val_loss: 9.1622e-04
# Epoch 45/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.0815e-04 - val_loss: 9.1739e-04
# Epoch 46/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.0223e-04 - val_loss: 8.9627e-04
# Epoch 47/50
# 67/67 [==============================] - 1s 17ms/step - loss: 4.7982e-04 - val_loss: 8.8924e-04
# Epoch 48/50
# 67/67 [==============================] - 1s 17ms/step - loss: 4.7499e-04 - val_loss: 8.9725e-04
# Epoch 49/50
# 67/67 [==============================] - 1s 16ms/step - loss: 4.5983e-04 - val_loss: 8.9038e-04
# Epoch 50/50
# 67/67 [==============================] - 1s 16ms/step - loss: 4.5756e-04 - val_loss: 9.0201e-04

# %%
import matplotlib.pyplot as plt

filtered_data = autoencoder.predict(X_test)

INDEX = 1

plt.plot(X_test[INDEX])
plt.plot(filtered_data[INDEX])
plt.legend(['original', 'filtered'])
plt.show()
# Out:
# 17/17 [==============================] - 0s 5ms/step
