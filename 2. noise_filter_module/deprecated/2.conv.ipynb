# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Input, Reshape, Conv1D, MaxPooling1D, Flatten, Dense, LeakyReLU
from tensorflow.keras import Sequential

def simple_autoencoder():
    autoencoder = Sequential([
        # Encoder
        Input(shape=(1000, 1)),
        Conv1D(16, 3, padding='same'),
        LeakyReLU(alpha=0.1),

        # Bottleneck
        Conv1D(8, 3, padding='same'),
        LeakyReLU(alpha=0.1),

        # Decoder
        Conv1D(16, 3, padding='same'),
        LeakyReLU(alpha=0.1),
        Conv1D(1, 3, activation='tanh', padding='same'),
        Reshape((1000, 1))
    ])

    return autoencoder
# Out:
# 2023-12-14 00:06:48.217112: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-14 00:06:48.231254: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-14 00:06:48.295763: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-14 00:06:48.297439: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-14 00:06:49.200227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
DIR = "../data/Raw/logRaws/"

NUM_SAMPLES = 2662
NUM_FEATURES = 1
NUM_FRAMES = 1000

file_names = os.listdir(DIR)
input_array = np.empty((NUM_SAMPLES, NUM_FRAMES, NUM_FEATURES))

# prepare data
def read_files(DIR):
    all_files = os.listdir(DIR)

    input_data = np.empty((0, 1), float)

    for file in all_files:
        file_path = os.path.join(DIR, file)
        df = pd.read_csv(file_path, usecols=[16], header=None)
        if df.shape[0] < 999:
            continue
        df = df.astype('float32')

        input_data = np.append(input_data, df, axis=0)
    input_data = input_data.reshape(NUM_SAMPLES, NUM_FRAMES, NUM_FEATURES)

    # divide by 16 to normalize
    input_data = input_data / 16

    return input_data

input_data = read_files(DIR)

input_data.shape
# Out:
# (2662, 1000, 1)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

X_train, X_test = train_test_split(input_data, test_size=0.2, random_state=42)

# compile autoencoder
autoencoder = simple_autoencoder()
autoencoder.compile(optimizer=Adam(learning_rate=0.0005), loss='mse')
autoencoder.summary()

# train autoencoder
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=32,
                validation_data=(X_test, X_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1000, 16)          64
#
#  leaky_re_lu (LeakyReLU)     (None, 1000, 16)          0
#
#  conv1d_1 (Conv1D)           (None, 1000, 8)           392
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 1000, 8)           0
#
#  conv1d_2 (Conv1D)           (None, 1000, 16)          400
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1000, 16)          0
#
#  conv1d_3 (Conv1D)           (None, 1000, 1)           49
#
#  reshape (Reshape)           (None, 1000, 1)           0
#
# =================================================================
# Total params: 905 (3.54 KB)
# Trainable params: 905 (3.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 67/67 [==============================] - 2s 17ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 2/50
# 67/67 [==============================] - 1s 20ms/step - loss: 7.2524e-04 - val_loss: 3.2304e-04
# Epoch 3/50
# 67/67 [==============================] - 1s 17ms/step - loss: 2.6510e-04 - val_loss: 2.0157e-04
# Epoch 4/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.6728e-04 - val_loss: 1.1545e-04
# Epoch 5/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.0126e-04 - val_loss: 7.6455e-05
# Epoch 6/50
# 67/67 [==============================] - 1s 18ms/step - loss: 7.1433e-05 - val_loss: 5.7116e-05
# Epoch 7/50
# 67/67 [==============================] - 1s 17ms/step - loss: 5.4049e-05 - val_loss: 4.4271e-05
# Epoch 8/50
# 67/67 [==============================] - 1s 16ms/step - loss: 4.1805e-05 - val_loss: 3.5030e-05
# Epoch 9/50
# 67/67 [==============================] - 1s 14ms/step - loss: 3.3259e-05 - val_loss: 2.9047e-05
# Epoch 10/50
# 67/67 [==============================] - 1s 15ms/step - loss: 2.7999e-05 - val_loss: 2.5235e-05
# Epoch 11/50
# 67/67 [==============================] - 1s 18ms/step - loss: 2.4633e-05 - val_loss: 2.2706e-05
# Epoch 12/50
# 67/67 [==============================] - 1s 16ms/step - loss: 2.2290e-05 - val_loss: 2.0873e-05
# Epoch 13/50
# 67/67 [==============================] - 1s 16ms/step - loss: 2.0548e-05 - val_loss: 1.9487e-05
# Epoch 14/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.9205e-05 - val_loss: 1.8346e-05
# Epoch 15/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.8122e-05 - val_loss: 1.7449e-05
# Epoch 16/50
# 67/67 [==============================] - 1s 14ms/step - loss: 1.7191e-05 - val_loss: 1.6586e-05
# Epoch 17/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.6337e-05 - val_loss: 1.5795e-05
# Epoch 18/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.5532e-05 - val_loss: 1.5053e-05
# Epoch 19/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.4793e-05 - val_loss: 1.4309e-05
# Epoch 20/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.4068e-05 - val_loss: 1.3651e-05
# Epoch 21/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.3435e-05 - val_loss: 1.3070e-05
# Epoch 22/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.2844e-05 - val_loss: 1.2526e-05
# Epoch 23/50
# 67/67 [==============================] - 1s 14ms/step - loss: 1.2299e-05 - val_loss: 1.1996e-05
# Epoch 24/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.1795e-05 - val_loss: 1.1517e-05
# Epoch 25/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1307e-05 - val_loss: 1.1037e-05
# Epoch 26/50
# 67/67 [==============================] - 1s 21ms/step - loss: 1.0855e-05 - val_loss: 1.0593e-05
# Epoch 27/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.0434e-05 - val_loss: 1.0214e-05
# Epoch 28/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.0049e-05 - val_loss: 9.8421e-06
# Epoch 29/50
# 67/67 [==============================] - 1s 14ms/step - loss: 9.7213e-06 - val_loss: 9.4457e-06
# Epoch 30/50
# 67/67 [==============================] - 1s 14ms/step - loss: 9.3422e-06 - val_loss: 9.1213e-06
# Epoch 31/50
# 67/67 [==============================] - 1s 14ms/step - loss: 9.0359e-06 - val_loss: 8.7700e-06
# Epoch 32/50
# 67/67 [==============================] - 1s 17ms/step - loss: 8.7097e-06 - val_loss: 8.4781e-06
# Epoch 33/50
# 67/67 [==============================] - 1s 14ms/step - loss: 8.4237e-06 - val_loss: 8.1960e-06
# Epoch 34/50
# 67/67 [==============================] - 1s 15ms/step - loss: 8.1353e-06 - val_loss: 7.9083e-06
# Epoch 35/50
# 67/67 [==============================] - 1s 16ms/step - loss: 7.8607e-06 - val_loss: 7.6573e-06
# Epoch 36/50
# 67/67 [==============================] - 1s 15ms/step - loss: 7.6133e-06 - val_loss: 7.4321e-06
# Epoch 37/50
# 67/67 [==============================] - 1s 13ms/step - loss: 7.3574e-06 - val_loss: 7.1359e-06
# Epoch 38/50
# 67/67 [==============================] - 1s 14ms/step - loss: 7.1106e-06 - val_loss: 6.9254e-06
# Epoch 39/50
# 67/67 [==============================] - 1s 13ms/step - loss: 6.8944e-06 - val_loss: 6.6732e-06
# Epoch 40/50
# 67/67 [==============================] - 1s 17ms/step - loss: 6.6878e-06 - val_loss: 6.4378e-06
# Epoch 41/50
# 67/67 [==============================] - 1s 18ms/step - loss: 6.4637e-06 - val_loss: 6.3698e-06
# Epoch 42/50
# 67/67 [==============================] - 1s 21ms/step - loss: 6.3067e-06 - val_loss: 6.1538e-06
# Epoch 43/50
# 67/67 [==============================] - 1s 17ms/step - loss: 6.0951e-06 - val_loss: 5.8492e-06
# Epoch 44/50
# 67/67 [==============================] - 1s 15ms/step - loss: 5.8835e-06 - val_loss: 5.6903e-06
# Epoch 45/50
# 67/67 [==============================] - 1s 15ms/step - loss: 5.7189e-06 - val_loss: 5.6129e-06
# Epoch 46/50
# 67/67 [==============================] - 1s 15ms/step - loss: 5.5903e-06 - val_loss: 5.3618e-06
# Epoch 47/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.3987e-06 - val_loss: 5.2290e-06
# Epoch 48/50
# 67/67 [==============================] - 1s 15ms/step - loss: 5.2554e-06 - val_loss: 5.0391e-06
# Epoch 49/50
# 67/67 [==============================] - 1s 16ms/step - loss: 5.0837e-06 - val_loss: 4.9816e-06
# Epoch 50/50
# 67/67 [==============================] - 1s 14ms/step - loss: 4.9662e-06 - val_loss: 4.7952e-06

# %%
import matplotlib.pyplot as plt

filtered_data = autoencoder.predict(X_test)

INDEX = 32

plt.figure(figsize=(15, 5))
plt.plot(X_test[INDEX])
plt.plot(filtered_data[INDEX])
plt.legend(['original', 'filtered'])
plt.show()
# Out:
# 17/17 [==============================] - 0s 4ms/step
