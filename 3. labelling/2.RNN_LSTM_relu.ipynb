# %%
import os
import pandas as pd
import numpy as np

DIR = "./data/Raw/logRaws/"

NUM_SAMPLES = 2662
NUM_FEATURES = 6
NUM_FRAMES = 1000

file_names = os.listdir(DIR)
input_array = np.empty((NUM_SAMPLES, NUM_FRAMES, NUM_FEATURES))
output_array = np.empty((NUM_SAMPLES, NUM_FRAMES, 1))

# prepare data
def read_files(DIR):
    all_files = os.listdir(DIR)

    input_data = np.empty((0, 6), float)
    output_data = np.empty((0, 1), int)

    for file in all_files:
        file_path = os.path.join(DIR, file)
        df = pd.read_csv(file_path, usecols=[1, 3, 19, 20, 21, 25, 26, 27], header=None)
        if df.shape[0] < 999:
            continue

        df.columns = ['frame', 'status', 'accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']
        df_input = df[['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']]
        df_input = df_input.astype('float32')
        df_output = df[['status']]
        df_output = df_output.astype('int')
        df_frames = df[['frame']]
        df_frames = df_frames.astype('int')

        input_data = np.append(input_data, df_input, axis=0)
        output_data = np.append(output_data, df_output, axis=0)

    input_data = input_data.reshape(NUM_SAMPLES, NUM_FRAMES, NUM_FEATURES)
    output_data = output_data.reshape(NUM_SAMPLES, NUM_FRAMES, 1)

    return input_data, output_data

input_data, output_data = read_files(DIR)

print(input_data.shape)
print(output_data.shape)
# Out:
# (2662, 1000, 6)
# (2662, 1000, 1)

# %%
from keras.utils import to_categorical

# one-hot encoding
output_data = to_categorical(output_data)

from sklearn.model_selection import train_test_split

# split data into train and remaining
X_train, X_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.2, random_state=42)

# build model
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(64, input_shape=(NUM_FRAMES, NUM_FEATURES), return_sequences=True),
    Dropout(0.2),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    Dense(5, activation='relu')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

# train model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# evaluate model
score = model.evaluate(X_test, y_test, batch_size=32)
print(score)

# save model
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 1000, 64)          18176
#
#  dropout_14 (Dropout)        (None, 1000, 64)          0
#
#  lstm_15 (LSTM)              (None, 1000, 64)          33024
#
#  dropout_15 (Dropout)        (None, 1000, 64)          0
#
#  dense_7 (Dense)             (None, 1000, 5)           325
#
# =================================================================
# Total params: 51525 (201.27 KB)
# Trainable params: 51525 (201.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 67/67 [==============================] - 101s 1s/step - loss: 0.5667 - accuracy: 0.6162 - val_loss: 0.3175 - val_accuracy: 0.7224
# Epoch 2/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2765 - accuracy: 0.7215 - val_loss: 0.2416 - val_accuracy: 0.7494
# Epoch 3/50
# 67/67 [==============================] - 91s 1s/step - loss: 0.3011 - accuracy: 0.7029 - val_loss: 0.2340 - val_accuracy: 0.7371
# Epoch 4/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2402 - accuracy: 0.7433 - val_loss: 0.2110 - val_accuracy: 0.7715
# Epoch 5/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2260 - accuracy: 0.7710 - val_loss: 0.1956 - val_accuracy: 0.8365
# Epoch 6/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2784 - accuracy: 0.7895 - val_loss: 0.2231 - val_accuracy: 0.8294
# Epoch 7/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2023 - accuracy: 0.8243 - val_loss: 0.1605 - val_accuracy: 0.8592
# Epoch 8/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2023 - accuracy: 0.8300 - val_loss: 0.1681 - val_accuracy: 0.8412
# Epoch 9/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2516 - accuracy: 0.7472 - val_loss: 0.2153 - val_accuracy: 0.7812
# Epoch 10/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2167 - accuracy: 0.7854 - val_loss: 0.1885 - val_accuracy: 0.8097
# Epoch 11/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2415 - accuracy: 0.7485 - val_loss: 0.2042 - val_accuracy: 0.7570
# Epoch 12/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2186 - accuracy: 0.7561 - val_loss: 0.2288 - val_accuracy: 0.7407
# Epoch 13/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2471 - accuracy: 0.7081 - val_loss: 0.2734 - val_accuracy: 0.5386
# Epoch 14/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2436 - accuracy: 0.7245 - val_loss: 0.2090 - val_accuracy: 0.7813
# Epoch 15/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2202 - accuracy: 0.7651 - val_loss: 0.1916 - val_accuracy: 0.8004
# Epoch 16/50
# 67/67 [==============================] - 92s 1s/step - loss: 0.2033 - accuracy: 0.8018 - val_loss: 0.1682 - val_accuracy: 0.8325
# Epoch 17/50
# 67/67 [==============================] - 94s 1s/step - loss: 0.2032 - accuracy: 0.8098 - val_loss: 0.2375 - val_accuracy: 0.7981
# Epoch 18/50
# 67/67 [==============================] - 94s 1s/step - loss: 0.2052 - accuracy: 0.8088 - val_loss: 0.2147 - val_accuracy: 0.8331
# Epoch 19/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2177 - accuracy: 0.7935 - val_loss: 0.2108 - val_accuracy: 0.7574
# Epoch 20/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2031 - accuracy: 0.8065 - val_loss: 0.1578 - val_accuracy: 0.8544
# Epoch 21/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.1815 - accuracy: 0.8352 - val_loss: 0.1569 - val_accuracy: 0.8549
# Epoch 22/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1721 - accuracy: 0.8506 - val_loss: 0.1465 - val_accuracy: 0.8680
# Epoch 23/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1782 - accuracy: 0.8326 - val_loss: 0.1392 - val_accuracy: 0.8746
# Epoch 24/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.1625 - accuracy: 0.8622 - val_loss: 0.1388 - val_accuracy: 0.8741
# Epoch 25/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2642 - accuracy: 0.7086 - val_loss: 0.2097 - val_accuracy: 0.7741
# Epoch 26/50
# 67/67 [==============================] - 94s 1s/step - loss: 0.2220 - accuracy: 0.7451 - val_loss: 0.2027 - val_accuracy: 0.7917
# Epoch 27/50
# 67/67 [==============================] - 94s 1s/step - loss: 0.2096 - accuracy: 0.7783 - val_loss: 0.1912 - val_accuracy: 0.8045
# Epoch 28/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.1986 - accuracy: 0.7947 - val_loss: 0.1819 - val_accuracy: 0.8050
# Epoch 29/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2067 - accuracy: 0.8004 - val_loss: 0.1813 - val_accuracy: 0.8238
# Epoch 30/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2421 - accuracy: 0.7344 - val_loss: 0.2155 - val_accuracy: 0.7965
# Epoch 31/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2171 - accuracy: 0.7888 - val_loss: 0.2516 - val_accuracy: 0.6971
# Epoch 32/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2484 - accuracy: 0.7345 - val_loss: 0.2055 - val_accuracy: 0.7849
# Epoch 33/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.2144 - accuracy: 0.7835 - val_loss: 0.1883 - val_accuracy: 0.8225
# Epoch 34/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2141 - accuracy: 0.7804 - val_loss: 0.1899 - val_accuracy: 0.8183
# Epoch 35/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2028 - accuracy: 0.8046 - val_loss: 0.1824 - val_accuracy: 0.8286
# Epoch 36/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.2063 - accuracy: 0.7888 - val_loss: 0.2782 - val_accuracy: 0.7544
# Epoch 37/50
# 67/67 [==============================] - 95s 1s/step - loss: 0.2293 - accuracy: 0.7759 - val_loss: 0.1872 - val_accuracy: 0.8172
# Epoch 38/50
# 67/67 [==============================] - 94s 1s/step - loss: 0.1922 - accuracy: 0.8189 - val_loss: 0.1603 - val_accuracy: 0.8448
# Epoch 39/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1762 - accuracy: 0.8455 - val_loss: 0.1488 - val_accuracy: 0.8667
# Epoch 40/50
# 67/67 [==============================] - 89s 1s/step - loss: 0.1682 - accuracy: 0.8545 - val_loss: 0.1416 - val_accuracy: 0.8693
# Epoch 41/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1666 - accuracy: 0.8548 - val_loss: 0.1460 - val_accuracy: 0.8713
# Epoch 42/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1618 - accuracy: 0.8597 - val_loss: 0.1373 - val_accuracy: 0.8760
# Epoch 43/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1549 - accuracy: 0.8669 - val_loss: 0.1418 - val_accuracy: 0.8629
# Epoch 44/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1583 - accuracy: 0.8656 - val_loss: 0.1305 - val_accuracy: 0.8795
# Epoch 45/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1689 - accuracy: 0.8408 - val_loss: 0.1328 - val_accuracy: 0.8809
# Epoch 46/50
# 67/67 [==============================] - 95s 1s/step - loss: 0.1460 - accuracy: 0.8782 - val_loss: 0.1253 - val_accuracy: 0.8914
# Epoch 47/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1454 - accuracy: 0.8789 - val_loss: 0.1363 - val_accuracy: 0.8753
# Epoch 48/50
# 67/67 [==============================] - 94s 1s/step - loss: 0.1486 - accuracy: 0.8739 - val_loss: 0.1200 - val_accuracy: 0.8895
# Epoch 49/50
# 67/67 [==============================] - 92s 1s/step - loss: 0.1399 - accuracy: 0.8867 - val_loss: 0.1137 - val_accuracy: 0.8960
# Epoch 50/50
# 67/67 [==============================] - 90s 1s/step - loss: 0.1393 - accuracy: 0.8848 - val_loss: 0.1159 - val_accuracy: 0.8982
# 17/17 [==============================] - 5s 288ms/step - loss: 0.1159 - accuracy: 0.8982
# [0.11588607728481293, 0.8982007503509521]
