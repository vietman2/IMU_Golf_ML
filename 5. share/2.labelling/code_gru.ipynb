# %%
from keras.utils import to_categorical

# one-hot encoding
output_data = to_categorical(output_data)

from sklearn.model_selection import train_test_split

# split data into train and remaining
X_train, X_remaining, y_train, y_remaining = train_test_split(input_data, output_data, test_size=0.4, random_state=42)

# split the remaining data into test set and validation set (equal split)
X_test, X_val, y_test, y_val = train_test_split(X_remaining, y_remaining, test_size=0.5, random_state=42)

# build model
from keras.models import Sequential
from keras.layers import GRU, Dropout, Dense

model = Sequential([
    GRU(64, input_shape=(NUM_FRAMES, NUM_FEATURES), return_sequences=True),
    Dropout(0.2),
    GRU(64, return_sequences=True),
    Dropout(0.2),
    Dense(5, activation='sigmoid')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

# train model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

# evaluate model
score = model.evaluate(X_test, y_test, batch_size=32)
print(score)

# save model
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_4 (GRU)                 (None, 1000, 64)          13824
#
#  dropout_4 (Dropout)         (None, 1000, 64)          0
#
#  gru_5 (GRU)                 (None, 1000, 64)          24960
#
#  dropout_5 (Dropout)         (None, 1000, 64)          0
#
#  dense_2 (Dense)             (None, 1000, 5)           325
#
# =================================================================
# Total params: 39109 (152.77 KB)
# Trainable params: 39109 (152.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 50/50 [==============================] - 44s 817ms/step - loss: 0.9898 - accuracy: 0.6237 - val_loss: 0.6006 - val_accuracy: 0.7304
# Epoch 2/50
# 50/50 [==============================] - 40s 795ms/step - loss: 0.5067 - accuracy: 0.7974 - val_loss: 0.3992 - val_accuracy: 0.8543
# Epoch 3/50
# 50/50 [==============================] - 40s 805ms/step - loss: 0.3414 - accuracy: 0.8812 - val_loss: 0.3131 - val_accuracy: 0.8957
# Epoch 4/50
# 50/50 [==============================] - 42s 842ms/step - loss: 0.2871 - accuracy: 0.8997 - val_loss: 0.2767 - val_accuracy: 0.9009
# Epoch 5/50
# 50/50 [==============================] - 40s 807ms/step - loss: 0.2503 - accuracy: 0.9128 - val_loss: 0.2580 - val_accuracy: 0.9067
# Epoch 6/50
# 50/50 [==============================] - 41s 818ms/step - loss: 0.2319 - accuracy: 0.9177 - val_loss: 0.2366 - val_accuracy: 0.9146
# Epoch 7/50
# 50/50 [==============================] - 43s 873ms/step - loss: 0.2156 - accuracy: 0.9234 - val_loss: 0.2373 - val_accuracy: 0.9106
# Epoch 8/50
# 50/50 [==============================] - 43s 861ms/step - loss: 0.2088 - accuracy: 0.9251 - val_loss: 0.2122 - val_accuracy: 0.9224
# Epoch 9/50
# 50/50 [==============================] - 43s 859ms/step - loss: 0.1949 - accuracy: 0.9287 - val_loss: 0.2053 - val_accuracy: 0.9236
# Epoch 10/50
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1831 - accuracy: 0.9327 - val_loss: 0.1902 - val_accuracy: 0.9296
# Epoch 11/50
# 50/50 [==============================] - 43s 861ms/step - loss: 0.1736 - accuracy: 0.9365 - val_loss: 0.2127 - val_accuracy: 0.9198
# Epoch 12/50
# 50/50 [==============================] - 41s 813ms/step - loss: 0.1728 - accuracy: 0.9361 - val_loss: 0.2239 - val_accuracy: 0.9178
# Epoch 13/50
# 50/50 [==============================] - 41s 827ms/step - loss: 0.1793 - accuracy: 0.9333 - val_loss: 0.1931 - val_accuracy: 0.9280
# Epoch 14/50
# 50/50 [==============================] - 41s 823ms/step - loss: 0.1634 - accuracy: 0.9384 - val_loss: 0.1829 - val_accuracy: 0.9344
# Epoch 15/50
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1558 - accuracy: 0.9418 - val_loss: 0.1683 - val_accuracy: 0.9377
# Epoch 16/50
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1549 - accuracy: 0.9417 - val_loss: 0.1675 - val_accuracy: 0.9389
# Epoch 17/50
# 50/50 [==============================] - 41s 813ms/step - loss: 0.1520 - accuracy: 0.9427 - val_loss: 0.1678 - val_accuracy: 0.9393
# Epoch 18/50
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1487 - accuracy: 0.9442 - val_loss: 0.1627 - val_accuracy: 0.9412
# Epoch 19/50
# 50/50 [==============================] - 41s 810ms/step - loss: 0.1449 - accuracy: 0.9457 - val_loss: 0.1625 - val_accuracy: 0.9413
# Epoch 20/50
# 50/50 [==============================] - 43s 860ms/step - loss: 0.1423 - accuracy: 0.9468 - val_loss: 0.1598 - val_accuracy: 0.9431
# Epoch 21/50
# 50/50 [==============================] - 43s 868ms/step - loss: 0.1384 - accuracy: 0.9470 - val_loss: 0.1554 - val_accuracy: 0.9440
# Epoch 22/50
# 50/50 [==============================] - 53s 1s/step - loss: 0.1361 - accuracy: 0.9487 - val_loss: 0.1620 - val_accuracy: 0.9416
# Epoch 23/50
# 50/50 [==============================] - 54s 1s/step - loss: 0.1368 - accuracy: 0.9484 - val_loss: 0.1567 - val_accuracy: 0.9444
# Epoch 24/50
# 50/50 [==============================] - 40s 802ms/step - loss: 0.1361 - accuracy: 0.9490 - val_loss: 0.1616 - val_accuracy: 0.9437
# Epoch 25/50
# 50/50 [==============================] - 41s 821ms/step - loss: 0.1309 - accuracy: 0.9503 - val_loss: 0.1566 - val_accuracy: 0.9449
# Epoch 26/50
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1310 - accuracy: 0.9504 - val_loss: 0.1753 - val_accuracy: 0.9388
# Epoch 27/50
# 50/50 [==============================] - 43s 858ms/step - loss: 0.1322 - accuracy: 0.9501 - val_loss: 0.1544 - val_accuracy: 0.9445
# Epoch 28/50
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1249 - accuracy: 0.9521 - val_loss: 0.1556 - val_accuracy: 0.9441
# Epoch 29/50
# 50/50 [==============================] - 41s 818ms/step - loss: 0.1262 - accuracy: 0.9521 - val_loss: 0.1565 - val_accuracy: 0.9447
# Epoch 30/50
# 50/50 [==============================] - 40s 805ms/step - loss: 0.1230 - accuracy: 0.9531 - val_loss: 0.1564 - val_accuracy: 0.9443
# Epoch 31/50
# 50/50 [==============================] - 41s 813ms/step - loss: 0.1235 - accuracy: 0.9520 - val_loss: 0.1525 - val_accuracy: 0.9459
# Epoch 32/50
# 50/50 [==============================] - 41s 819ms/step - loss: 0.1178 - accuracy: 0.9547 - val_loss: 0.1611 - val_accuracy: 0.9431
# Epoch 33/50
# 50/50 [==============================] - 40s 804ms/step - loss: 0.1180 - accuracy: 0.9544 - val_loss: 0.1579 - val_accuracy: 0.9439
# Epoch 34/50
# 50/50 [==============================] - 44s 892ms/step - loss: 0.1312 - accuracy: 0.9508 - val_loss: 0.1514 - val_accuracy: 0.9485
# Epoch 35/50
# 50/50 [==============================] - 44s 871ms/step - loss: 0.1214 - accuracy: 0.9535 - val_loss: 0.1550 - val_accuracy: 0.9456
# Epoch 36/50
# 50/50 [==============================] - 41s 822ms/step - loss: 0.1138 - accuracy: 0.9560 - val_loss: 0.1580 - val_accuracy: 0.9433
# Epoch 37/50
# 50/50 [==============================] - 40s 812ms/step - loss: 0.1110 - accuracy: 0.9574 - val_loss: 0.1589 - val_accuracy: 0.9455
# Epoch 38/50
# 50/50 [==============================] - 40s 805ms/step - loss: 0.1125 - accuracy: 0.9568 - val_loss: 0.1482 - val_accuracy: 0.9491
# Epoch 39/50
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1092 - accuracy: 0.9580 - val_loss: 0.1589 - val_accuracy: 0.9441
# Epoch 40/50
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1118 - accuracy: 0.9578 - val_loss: 0.1544 - val_accuracy: 0.9455
# Epoch 41/50
# 50/50 [==============================] - 42s 834ms/step - loss: 0.1092 - accuracy: 0.9582 - val_loss: 0.1496 - val_accuracy: 0.9476
# Epoch 42/50
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1132 - accuracy: 0.9565 - val_loss: 0.1464 - val_accuracy: 0.9496
# Epoch 43/50
# 50/50 [==============================] - 40s 798ms/step - loss: 0.1048 - accuracy: 0.9598 - val_loss: 0.1630 - val_accuracy: 0.9452
# Epoch 44/50
# 50/50 [==============================] - 40s 800ms/step - loss: 0.1034 - accuracy: 0.9608 - val_loss: 0.1541 - val_accuracy: 0.9471
# Epoch 45/50
# 50/50 [==============================] - 41s 813ms/step - loss: 0.1024 - accuracy: 0.9606 - val_loss: 0.1635 - val_accuracy: 0.9416
# Epoch 46/50
# 50/50 [==============================] - 41s 817ms/step - loss: 0.1066 - accuracy: 0.9587 - val_loss: 0.1482 - val_accuracy: 0.9477
# Epoch 47/50
# 50/50 [==============================] - 44s 877ms/step - loss: 0.1086 - accuracy: 0.9582 - val_loss: 0.1587 - val_accuracy: 0.9448
# Epoch 48/50
# 50/50 [==============================] - 60s 1s/step - loss: 0.1074 - accuracy: 0.9588 - val_loss: 0.1456 - val_accuracy: 0.9475
# Epoch 49/50
# 50/50 [==============================] - 51s 1s/step - loss: 0.0996 - accuracy: 0.9621 - val_loss: 0.1434 - val_accuracy: 0.9497
# Epoch 50/50
# 50/50 [==============================] - 44s 882ms/step - loss: 0.0975 - accuracy: 0.9631 - val_loss: 0.1553 - val_accuracy: 0.9482
# 17/17 [==============================] - 4s 238ms/step - loss: 0.1395 - accuracy: 0.9539
# [0.13946732878684998, 0.9539285898208618]

# %%
import tensorflow as tf

# Save the model
export_path = "./GRU/1"
tf.saved_model.save(model, export_path)
# Out:
# INFO:tensorflow:Assets written to: ./GRU/1/assets
# INFO:tensorflow:Assets written to: ./GRU/1/assets
