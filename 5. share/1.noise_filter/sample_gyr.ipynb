# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D, Reshape, Layer, Dropout
)
from tensorflow.keras import Sequential

class CustomPadding(Layer):
    def __init__(self, padding_size, **kwargs):
        super(CustomPadding, self).__init__(**kwargs)
        self.padding_size = padding_size

    def call(self, inputs):
        initial_values = inputs[:, 0:1, :, :]
        final_values = inputs[:, -1:, :, :]

        initial_padding = tf.tile(initial_values, [1, self.padding_size, 1, 1])
        final_padding = tf.tile(final_values, [1, self.padding_size, 1, 1])

        return tf.concat([initial_padding, inputs, final_padding], axis=1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1] + self.padding_size * 2, input_shape[2], input_shape[3])

class RemovePadding(Layer):
    def __init__(self, padding_size, **kwargs):
        super(RemovePadding, self).__init__(**kwargs)
        self.padding_size = padding_size

    def call(self, inputs):
        return inputs[:, self.padding_size:-self.padding_size, :, :]

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1] - self.padding_size * 2, input_shape[2], input_shape[3])

def create_autoencoder():
    autoencoder = Sequential([
        # Pre-Processing
        Input(shape=(1000, 1)),
        Reshape((1000, 1, 1)),
        CustomPadding(padding_size=10),

        # Encoder
        Conv2D(8, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 1), padding='same'),

        # Decoder
        UpSampling2D((2, 1)),
        Conv2D(8, (3, 3), activation='relu', padding='same'),

        # Post-Processing
        Conv2D(1, (3, 3), activation='tanh', padding='same'),
        RemovePadding(padding_size=10),
        Reshape((1000, 1))
    ])

    return autoencoder
# Out:
# 2023-12-14 00:39:04.985468: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-14 00:39:04.989923: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-14 00:39:05.070266: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-14 00:39:05.072894: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-14 00:39:06.443864: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(input_data, test_size=0.2, random_state=42)

# compile autoencoder
autoencoder = create_autoencoder()
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()

# train autoencoder
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=32,
                validation_data=(X_test, X_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 1000, 1, 1)        0
#
#  custom_padding (CustomPadd  (None, 1020, 1, 1)        0
#  ing)
#
#  conv2d (Conv2D)             (None, 1020, 1, 8)        80
#
#  max_pooling2d (MaxPooling2  (None, 510, 1, 8)         0
#  D)
#
#  up_sampling2d (UpSampling2  (None, 1020, 1, 8)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 1020, 1, 8)        584
#
#  conv2d_2 (Conv2D)           (None, 1020, 1, 1)        73
#
#  remove_padding (RemovePadd  (None, 1000, 1, 1)        0
#  ing)
#
#  reshape_1 (Reshape)         (None, 1000, 1)           0
#
# =================================================================
# Total params: 737 (2.88 KB)
# Trainable params: 737 (2.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 67/67 [==============================] - 2s 23ms/step - loss: 1.2866e-06 - val_loss: 8.1576e-07
# Epoch 2/50
# 67/67 [==============================] - 2s 24ms/step - loss: 5.7655e-07 - val_loss: 2.7704e-07
# Epoch 3/50
# 67/67 [==============================] - 1s 18ms/step - loss: 2.0958e-07 - val_loss: 1.2351e-07
# Epoch 4/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.4195e-07 - val_loss: 1.1333e-07
# Epoch 5/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.3228e-07 - val_loss: 1.1235e-07
# Epoch 6/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.3312e-07 - val_loss: 1.1150e-07
# Epoch 7/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.5940e-07 - val_loss: 1.1034e-07
# Epoch 8/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1795e-07 - val_loss: 1.0846e-07
# Epoch 9/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.2719e-07 - val_loss: 1.1118e-07
# Epoch 10/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.4616e-07 - val_loss: 1.0723e-07
# Epoch 11/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.2173e-07 - val_loss: 1.0689e-07
# Epoch 12/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.2540e-07 - val_loss: 1.1306e-07
# Epoch 13/50
# 67/67 [==============================] - 1s 22ms/step - loss: 1.2855e-07 - val_loss: 1.2318e-07
# Epoch 14/50
# 67/67 [==============================] - 1s 20ms/step - loss: 1.4300e-07 - val_loss: 1.1910e-07
# Epoch 15/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.1499e-07 - val_loss: 1.0520e-07
# Epoch 16/50
# 67/67 [==============================] - 1s 18ms/step - loss: 2.1326e-07 - val_loss: 1.2445e-07
# Epoch 17/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1535e-07 - val_loss: 1.0435e-07
# Epoch 18/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1194e-07 - val_loss: 1.0175e-07
# Epoch 19/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1021e-07 - val_loss: 1.0017e-07
# Epoch 20/50
# 67/67 [==============================] - 1s 20ms/step - loss: 1.2040e-07 - val_loss: 1.0035e-07
# Epoch 21/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.2042e-07 - val_loss: 1.0543e-07
# Epoch 22/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.3221e-07 - val_loss: 1.2948e-07
# Epoch 23/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1433e-07 - val_loss: 9.7499e-08
# Epoch 24/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1215e-07 - val_loss: 1.8070e-07
# Epoch 25/50
# 67/67 [==============================] - 1s 20ms/step - loss: 1.1856e-07 - val_loss: 1.6847e-07
# Epoch 26/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.1873e-07 - val_loss: 1.2865e-07
# Epoch 27/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.3141e-07 - val_loss: 1.1818e-07
# Epoch 28/50
# 67/67 [==============================] - 1s 20ms/step - loss: 1.0645e-07 - val_loss: 9.4352e-08
# Epoch 29/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.2670e-07 - val_loss: 9.3853e-08
# Epoch 30/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.0478e-07 - val_loss: 9.4441e-08
# Epoch 31/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.2091e-07 - val_loss: 9.2514e-08
# Epoch 32/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1673e-07 - val_loss: 1.1909e-07
# Epoch 33/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.0734e-07 - val_loss: 1.1683e-07
# Epoch 34/50
# 67/67 [==============================] - 1s 21ms/step - loss: 1.2473e-07 - val_loss: 9.2194e-08
# Epoch 35/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.0032e-07 - val_loss: 8.9880e-08
# Epoch 36/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.2166e-07 - val_loss: 8.9556e-08
# Epoch 37/50
# 67/67 [==============================] - 1s 19ms/step - loss: 1.0489e-07 - val_loss: 1.2809e-07
# Epoch 38/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.0938e-07 - val_loss: 1.0194e-07
# Epoch 39/50
# 67/67 [==============================] - 1s 18ms/step - loss: 1.1634e-07 - val_loss: 9.7912e-08
# Epoch 40/50
# 67/67 [==============================] - 1s 16ms/step - loss: 9.7571e-08 - val_loss: 1.2548e-07
# Epoch 41/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.2641e-07 - val_loss: 8.6472e-08
# Epoch 42/50
# 67/67 [==============================] - 1s 16ms/step - loss: 9.4485e-08 - val_loss: 8.5264e-08
# Epoch 43/50
# 67/67 [==============================] - 1s 15ms/step - loss: 1.2085e-07 - val_loss: 9.1864e-08
# Epoch 44/50
# 67/67 [==============================] - 1s 16ms/step - loss: 9.3364e-08 - val_loss: 8.5838e-08
# Epoch 45/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.0839e-07 - val_loss: 8.5899e-08
# Epoch 46/50
# 67/67 [==============================] - 1s 17ms/step - loss: 1.0382e-07 - val_loss: 8.4795e-08
# Epoch 47/50
# 67/67 [==============================] - 1s 16ms/step - loss: 1.1046e-07 - val_loss: 8.6239e-08
# Epoch 48/50
# 67/67 [==============================] - 1s 20ms/step - loss: 9.8831e-08 - val_loss: 8.1468e-08
# Epoch 49/50
# 67/67 [==============================] - 2s 23ms/step - loss: 1.1267e-07 - val_loss: 1.5575e-07
# Epoch 50/50
# 67/67 [==============================] - 1s 20ms/step - loss: 9.6730e-08 - val_loss: 7.9852e-08

# %%
import tensorflow as tf

# save model
export_path = "./autoencoder/single_axis/gyro_x"
tf.saved_model.save(autoencoder, export_path)
# Out:
# INFO:tensorflow:Assets written to: ./autoencoder/single_axis/gyro_x/assets
# INFO:tensorflow:Assets written to: ./autoencoder/single_axis/gyro_x/assets
